# %%
import sys
import logging
import gym
from gym import spaces
import numpy as np
import networkx as nx
import cyberbattle.simulation.actions as actions
import cyberbattle._env.cyberbattle_env as cyberbattle_env
import cyberbattle.agents.random_agent as random_agent
import cyberbattle.samples.chainpattern.chainpattern as chainpattern
import importlib
import cyberbattle.agents.baseline.learner as learner
import cyberbattle.agents.baseline.plotting as p
import cyberbattle.agents.baseline.agent_wrapper as w
import cyberbattle.agents.baseline.agent_randomcredlookup as rca
import cyberbattle.agents.baseline.agent_tabularqlearning as tqa
import cyberbattle.agents.baseline.agent_dql as dqla
from cyberbattle.agents.baseline.agent_wrapper import Verbosity

# %%
gym_env = gym.make('CyberBattleCBSHH-v0')

iteration_count = 500
training_episode_count = 50
eval_episode_count = 10

# %%
gym_env.environment.plot_environment_graph()

# %%
ep = w.EnvironmentBounds.of_identifiers(
    maximum_node_count=12,
    maximum_total_credentials=5,
    identifiers=gym_env.identifiers
)

# %%
credlookup_run = learner.epsilon_greedy_search(
    gym_env,
    ep,
    learner=rca.CredentialCacheExploiter(),
    episode_count=10,
    iteration_count=iteration_count,
    epsilon=0.90,
    render=False,
    epsilon_exponential_decay=2000,
    epsilon_minimum=0.01,
    verbosity=Verbosity.Quiet,
    title="Credential lookups (ϵ-greedy)"
)
# Out:
# ###### Credential lookups (ϵ-greedy)
# Learning with: episode_count=10,iteration_count=500,ϵ=0.9,ϵ_min=0.01, ϵ_expdecay=2000,
#   ## Episode: 1/10 'Credential lookups (ϵ-greedy)' ϵ=0.9000,
# Episode 1|Iteration 69|reward: 4483.0|last_reward_at:   69|Elapsed Time: 0:00:00||
#   Episode 1 ended at t=69
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 6/14 (0.30)
#     explore-remote: 3/41 (0.07)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 3/2 (0.60)
#   exploit deflected to exploration: 2
#   ## Episode: 2/10 'Credential lookups (ϵ-greedy)' ϵ=0.8702,
# Episode 2|Iteration 79|reward: 4483.0|last_reward_at:   79|Elapsed Time: 0:00:00||
#   Episode 2 ended at t=79
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 6/13 (0.32)
#     explore-remote: 3/48 (0.06)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 3/6 (0.33)
#   exploit deflected to exploration: 4
#   ## Episode: 3/10 'Credential lookups (ϵ-greedy)' ϵ=0.8369,
# Episode 3|Iteration 43|reward: 4477.0|last_reward_at:   43|Elapsed Time: 0:00:00||
#   Episode 3 ended at t=43
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 5/7 (0.42)
#     explore-remote: 3/23 (0.12)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 3/2 (0.60)
#   exploit deflected to exploration: 6
#   ## Episode: 4/10 'Credential lookups (ϵ-greedy)' ϵ=0.8193,
# Episode 4|Iteration 48|reward: 4477.0|last_reward_at:   48|Elapsed Time: 0:00:00||
#   Episode 4 ended at t=48
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 5/3 (0.62)
#     explore-remote: 3/29 (0.09)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 3/5 (0.38)
#   exploit deflected to exploration: 2
#   ## Episode: 5/10 'Credential lookups (ϵ-greedy)' ϵ=0.8001,
# Episode 5|Iteration 55|reward: 4477.0|last_reward_at:   55|Elapsed Time: 0:00:00||
#   Episode 5 ended at t=55
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 5/7 (0.42)
#     explore-remote: 3/32 (0.09)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 3/5 (0.38)
#   exploit deflected to exploration: 9
#   ## Episode: 6/10 'Credential lookups (ϵ-greedy)' ϵ=0.7787,
# Episode 6|Iteration 147|reward: 4483.0|last_reward_at:  147|Elapsed Time: 0:00:00||
#   Episode 6 ended at t=147
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 6/29 (0.17)
#     explore-remote: 2/103 (0.02)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 4/3 (0.57)
#   exploit deflected to exploration: 23
#   ## Episode: 7/10 'Credential lookups (ϵ-greedy)' ϵ=0.7242,
# Episode 7|Iteration 104|reward: 4483.0|last_reward_at:  104|Elapsed Time: 0:00:00||
#   Episode 7 ended at t=104
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 6/20 (0.23)
#     explore-remote: 3/63 (0.05)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 3/9 (0.25)
#   exploit deflected to exploration: 24
#   ## Episode: 8/10 'Credential lookups (ϵ-greedy)' ϵ=0.6881,
# Episode 8|Iteration 55|reward: 4483.0|last_reward_at:   55|Elapsed Time: 0:00:00||
#   Episode 8 ended at t=55
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 6/9 (0.40)
#     explore-remote: 2/33 (0.06)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 4/1 (0.80)
#   exploit deflected to exploration: 16
#   ## Episode: 9/10 'Credential lookups (ϵ-greedy)' ϵ=0.6697,
# Episode 9|Iteration 49|reward: 4477.0|last_reward_at:   49|Elapsed Time: 0:00:00||
#   Episode 9 ended at t=49
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 5/6 (0.45)
#     explore-remote: 3/19 (0.14)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 3/13 (0.19)
#   exploit deflected to exploration: 4
#   ## Episode: 10/10 'Credential lookups (ϵ-greedy)' ϵ=0.6537,
# Episode 10|Iteration 42|reward: 4483.0|last_reward_at:   42|Elapsed Time: 0:00:00||
#   Episode 10 ended at t=42
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 6/1 (0.86)
#     explore-remote: 3/25 (0.11)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 3/4 (0.43)
#   exploit deflected to exploration: 9
# simulation ended

# %%
dql_run = learner.epsilon_greedy_search(
    cyberbattle_gym_env=gym_env,
    environment_properties=ep,
    learner=dqla.DeepQLearnerPolicy(
        ep=ep,
        gamma=0.015,
        replay_memory_size=10000,
        target_update=4,
        batch_size=512,
        # torch default learning rate is 1e-2
        # a large value helps converge in less episodes
        learning_rate=0.01
    ),
    episode_count=training_episode_count,
    iteration_count=iteration_count,
    epsilon=0.90,
    epsilon_exponential_decay=2000,
    epsilon_minimum=0.1,
    verbosity=Verbosity.Quiet,
    render=False,
    plot_episodes_length=False,
    title="DQL"
)
# Out:
# ###### DQL
# Learning with: episode_count=50,iteration_count=500,ϵ=0.9,ϵ_min=0.1, ϵ_expdecay=2000,γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
#   ## Episode: 1/50 'DQL' ϵ=0.9000, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 1|Iteration 7|reward:   59.0|last_reward_at:    7|Elapsed Time: 0:00:00||/home/jupyter-hoodit/cyberbattle/CBSHH/cyberbattle/agents/baseline/agent_dql.py:382: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   state_batch = torch.tensor(states_to_consider).to(device)
# Episode 1|Iteration 500|reward:  174.0|last_reward_at:  182|Elapsed Time: 0:00:01||
#   Episode 1 stopped at t=500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 5/60 (0.08)
#     explore-remote: 2/173 (0.01)
#     explore-connect: 1/179 (0.01)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/80 (0.00)
#   exploit deflected to exploration: 0
#   ## Episode: 2/50 'DQL' ϵ=0.7234, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 2|Iteration 267|reward: 4483.0|last_reward_at:  267|Elapsed Time: 0:00:01||
#   Episode 2 ended at t=267
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 5/29 (0.15)
#     explore-remote: 3/94 (0.03)
#     explore-connect: 3/63 (0.05)
#     exploit-local: 1/28 (0.03)
#     exploit-remote: 0/4 (0.00)
#     exploit-connect: 0/37 (0.00)
#   exploit deflected to exploration: 9
#   ## Episode: 3/50 'DQL' ϵ=0.6455, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 3|Iteration 408|reward: 4483.0|last_reward_at:  408|Elapsed Time: 0:00:02||
#   Episode 3 ended at t=408
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 3/38 (0.07)
#     explore-remote: 3/105 (0.03)
#     explore-connect: 2/100 (0.02)
#     exploit-local: 3/70 (0.04)
#     exploit-remote: 0/21 (0.00)
#     exploit-connect: 1/62 (0.02)
#   exploit deflected to exploration: 12
#   ## Episode: 4/50 'DQL' ϵ=0.5448, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 4|Iteration 172|reward: 4483.0|last_reward_at:  172|Elapsed Time: 0:00:01||
#   Episode 4 ended at t=172
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 3/10 (0.23)
#     explore-remote: 2/38 (0.05)
#     explore-connect: 0/42 (0.00)
#     exploit-local: 3/40 (0.07)
#     exploit-remote: 1/14 (0.07)
#     exploit-connect: 3/16 (0.16)
#   exploit deflected to exploration: 9
#   ## Episode: 5/50 'DQL' ϵ=0.5081, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 5|Iteration 500|reward:  174.0|last_reward_at:   84|Elapsed Time: 0:00:04||
#   Episode 5 stopped at t=500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/29 (0.03)
#     explore-remote: 2/102 (0.02)
#     explore-connect: 0/84 (0.00)
#     exploit-local: 4/266 (0.01)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 1/11 (0.08)
#   exploit deflected to exploration: 0
#   ## Episode: 6/50 'DQL' ϵ=0.4179, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 6|Iteration 500|reward:  174.0|last_reward_at:  163|Elapsed Time: 0:00:03||
#   Episode 6 stopped at t=500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 2/38 (0.05)
#     explore-remote: 2/86 (0.02)
#     explore-connect: 0/82 (0.00)
#     exploit-local: 3/284 (0.01)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 1/2 (0.33)
#   exploit deflected to exploration: 0
#   ## Episode: 7/50 'DQL' ϵ=0.3475, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 7|Iteration 500|reward:  174.0|last_reward_at:   60|Elapsed Time: 0:00:03||
#   Episode 7 stopped at t=500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/45 (0.02)
#     explore-remote: 2/73 (0.03)
#     explore-connect: 1/84 (0.01)
#     exploit-local: 4/289 (0.01)
#     exploit-remote: 0/1 (0.00)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 37
#   ## Episode: 8/50 'DQL' ϵ=0.2928, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 8|Iteration 500|reward:  174.0|last_reward_at:   64|Elapsed Time: 0:00:03||
#   Episode 8 stopped at t=500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 2/27 (0.07)
#     explore-remote: 2/46 (0.04)
#     explore-connect: 0/41 (0.00)
#     exploit-local: 3/370 (0.01)
#     exploit-remote: 0/2 (0.00)
#     exploit-connect: 1/6 (0.14)
#   exploit deflected to exploration: 1
#   ## Episode: 9/50 'DQL' ϵ=0.2501, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 9|Iteration 140|reward: 4483.0|last_reward_at:  140|Elapsed Time: 0:00:01||
#   Episode 9 ended at t=140
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 0/9 (0.00)
#     explore-remote: 1/19 (0.05)
#     explore-connect: 0/16 (0.00)
#     exploit-local: 6/52 (0.10)
#     exploit-remote: 2/26 (0.07)
#     exploit-connect: 3/6 (0.33)
#   exploit deflected to exploration: 17
#   ## Episode: 10/50 'DQL' ϵ=0.2400, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 10|Iteration 66|reward: 4483.0|last_reward_at:   66|Elapsed Time: 0:00:00||
#   Episode 10 ended at t=66
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 0/5 (0.00)
#     explore-remote: 2/21 (0.09)
#     explore-connect: 0/4 (0.00)
#     exploit-local: 6/8 (0.43)
#     exploit-remote: 1/12 (0.08)
#     exploit-connect: 3/4 (0.43)
#   exploit deflected to exploration: 9
#   ## Episode: 11/50 'DQL' ϵ=0.2355, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 11|Iteration 97|reward: 4483.0|last_reward_at:   97|Elapsed Time: 0:00:00||
#   Episode 11 ended at t=97
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/7 (0.12)
#     explore-remote: 2/14 (0.12)
#     explore-connect: 0/16 (0.00)
#     exploit-local: 5/6 (0.45)
#     exploit-remote: 1/35 (0.03)
#     exploit-connect: 3/7 (0.30)
#   exploit deflected to exploration: 19
#   ## Episode: 12/50 'DQL' ϵ=0.2290, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 12|Iteration 236|reward: 4483.0|last_reward_at:  236|Elapsed Time: 0:00:01||
#   Episode 12 ended at t=236
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 2/7 (0.22)
#     explore-remote: 2/36 (0.05)
#     explore-connect: 0/22 (0.00)
#     exploit-local: 5/38 (0.12)
#     exploit-remote: 0/116 (0.00)
#     exploit-connect: 3/5 (0.38)
#   exploit deflected to exploration: 2
#   ## Episode: 13/50 'DQL' ϵ=0.2147, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 13|Iteration 68|reward: 4483.0|last_reward_at:   68|Elapsed Time: 0:00:00||
#   Episode 13 ended at t=68
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/2 (0.33)
#     explore-remote: 0/10 (0.00)
#     explore-connect: 1/10 (0.09)
#     exploit-local: 5/6 (0.45)
#     exploit-remote: 2/18 (0.10)
#     exploit-connect: 3/10 (0.23)
#   exploit deflected to exploration: 7
#   ## Episode: 14/50 'DQL' ϵ=0.2108, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 14|Iteration 81|reward: 4483.0|last_reward_at:   81|Elapsed Time: 0:00:00||
#   Episode 14 ended at t=81
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/1 (0.50)
#     explore-remote: 1/9 (0.10)
#     explore-connect: 1/11 (0.08)
#     exploit-local: 5/20 (0.20)
#     exploit-remote: 1/18 (0.05)
#     exploit-connect: 3/10 (0.23)
#   exploit deflected to exploration: 9
#   ## Episode: 15/50 'DQL' ϵ=0.2064, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 15|Iteration 28|reward: 4483.0|last_reward_at:   28|Elapsed Time: 0:00:00||
#   Episode 15 ended at t=28
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 0/0 (NaN)
#     explore-remote: 0/3 (0.00)
#     explore-connect: 1/2 (0.33)
#     exploit-local: 6/3 (0.67)
#     exploit-remote: 2/2 (0.50)
#     exploit-connect: 3/6 (0.33)
#   exploit deflected to exploration: 0
#   ## Episode: 16/50 'DQL' ϵ=0.2050, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 16|Iteration 90|reward: 4483.0|last_reward_at:   90|Elapsed Time: 0:00:00||
#   Episode 16 ended at t=90
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 0/7 (0.00)
#     explore-remote: 1/14 (0.07)
#     explore-connect: 0/10 (0.00)
#     exploit-local: 6/5 (0.55)
#     exploit-remote: 2/15 (0.12)
#     exploit-connect: 3/27 (0.10)
#   exploit deflected to exploration: 8
#   ## Episode: 17/50 'DQL' ϵ=0.2003, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 17|Iteration 68|reward: 4483.0|last_reward_at:   68|Elapsed Time: 0:00:00||
#   Episode 17 ended at t=68
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/3 (0.25)
#     explore-remote: 0/6 (0.00)
#     explore-connect: 0/9 (0.00)
#     exploit-local: 5/10 (0.33)
#     exploit-remote: 3/23 (0.12)
#     exploit-connect: 3/5 (0.38)
#   exploit deflected to exploration: 1
#   ## Episode: 18/50 'DQL' ϵ=0.1970, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 18|Iteration 216|reward: 4483.0|last_reward_at:  216|Elapsed Time: 0:00:01||
#   Episode 18 ended at t=216
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 0/7 (0.00)
#     explore-remote: 2/24 (0.08)
#     explore-connect: 0/21 (0.00)
#     exploit-local: 6/46 (0.12)
#     exploit-remote: 1/39 (0.03)
#     exploit-connect: 3/67 (0.04)
#   exploit deflected to exploration: 12
#   ## Episode: 19/50 'DQL' ϵ=0.1871, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 19|Iteration 77|reward: 4483.0|last_reward_at:   77|Elapsed Time: 0:00:00||
#   Episode 19 ended at t=77
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/7 (0.12)
#     explore-remote: 1/5 (0.17)
#     explore-connect: 0/6 (0.00)
#     exploit-local: 5/16 (0.24)
#     exploit-remote: 2/17 (0.11)
#     exploit-connect: 3/14 (0.18)
#   exploit deflected to exploration: 5
#   ## Episode: 20/50 'DQL' ϵ=0.1838, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 20|Iteration 35|reward: 4477.0|last_reward_at:   35|Elapsed Time: 0:00:00||
#   Episode 20 ended at t=35
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 0/0 (NaN)
#     explore-remote: 1/0 (1.00)
#     explore-connect: 1/4 (0.20)
#     exploit-local: 5/4 (0.56)
#     exploit-remote: 1/10 (0.09)
#     exploit-connect: 3/6 (0.33)
#   exploit deflected to exploration: 0
#   ## Episode: 21/50 'DQL' ϵ=0.1823, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 21|Iteration 108|reward: 4483.0|last_reward_at:  108|Elapsed Time: 0:00:01||
#   Episode 21 ended at t=108
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 0/2 (0.00)
#     explore-remote: 0/17 (0.00)
#     explore-connect: 0/28 (0.00)
#     exploit-local: 7/29 (0.19)
#     exploit-remote: 2/18 (0.10)
#     exploit-connect: 3/2 (0.60)
#   exploit deflected to exploration: 27
#   ## Episode: 22/50 'DQL' ϵ=0.1780, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 22|Iteration 164|reward: 4483.0|last_reward_at:  164|Elapsed Time: 0:00:01||
#   Episode 22 ended at t=164
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 0/3 (0.00)
#     explore-remote: 2/20 (0.09)
#     explore-connect: 0/18 (0.00)
#     exploit-local: 6/40 (0.13)
#     exploit-remote: 1/47 (0.02)
#     exploit-connect: 3/24 (0.11)
#   exploit deflected to exploration: 16
#   ## Episode: 23/50 'DQL' ϵ=0.1719, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 23|Iteration 52|reward: 4483.0|last_reward_at:   52|Elapsed Time: 0:00:00||
#   Episode 23 ended at t=52
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 2/3 (0.40)
#     explore-remote: 1/8 (0.11)
#     explore-connect: 0/2 (0.00)
#     exploit-local: 4/2 (0.67)
#     exploit-remote: 1/17 (0.06)
#     exploit-connect: 4/8 (0.33)
#   exploit deflected to exploration: 3
#   ## Episode: 24/50 'DQL' ϵ=0.1700, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 24|Iteration 103|reward: 4483.0|last_reward_at:  103|Elapsed Time: 0:00:00||
#   Episode 24 ended at t=103
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 0/3 (0.00)
#     explore-remote: 1/7 (0.12)
#     explore-connect: 0/6 (0.00)
#     exploit-local: 7/12 (0.37)
#     exploit-remote: 1/23 (0.04)
#     exploit-connect: 3/40 (0.07)
#   exploit deflected to exploration: 2
#   ## Episode: 25/50 'DQL' ϵ=0.1665, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 25|Iteration 93|reward: 4483.0|last_reward_at:   93|Elapsed Time: 0:00:01||
#   Episode 25 ended at t=93
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 0/3 (0.00)
#     explore-remote: 3/19 (0.14)
#     explore-connect: 0/15 (0.00)
#     exploit-local: 6/20 (0.23)
#     exploit-remote: 0/10 (0.00)
#     exploit-connect: 3/14 (0.18)
#   exploit deflected to exploration: 22
#   ## Episode: 26/50 'DQL' ϵ=0.1635, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 26|Iteration 110|reward: 4483.0|last_reward_at:  110|Elapsed Time: 0:00:00||
#   Episode 26 ended at t=110
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 0/4 (0.00)
#     explore-remote: 1/5 (0.17)
#     explore-connect: 0/10 (0.00)
#     exploit-local: 6/39 (0.13)
#     exploit-remote: 2/8 (0.20)
#     exploit-connect: 3/32 (0.09)
#   exploit deflected to exploration: 6
#   ## Episode: 27/50 'DQL' ϵ=0.1601, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 27|Iteration 125|reward: 4483.0|last_reward_at:  125|Elapsed Time: 0:00:00||
#   Episode 27 ended at t=125
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/0 (1.00)
#     explore-remote: 0/15 (0.00)
#     explore-connect: 1/13 (0.07)
#     exploit-local: 5/42 (0.11)
#     exploit-remote: 2/29 (0.06)
#     exploit-connect: 3/14 (0.18)
#   exploit deflected to exploration: 9
#   ## Episode: 28/50 'DQL' ϵ=0.1564, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 28|Iteration 113|reward: 4483.0|last_reward_at:  113|Elapsed Time: 0:00:00||
#   Episode 28 ended at t=113
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/7 (0.12)
#     explore-remote: 1/13 (0.07)
#     explore-connect: 0/7 (0.00)
#     exploit-local: 5/29 (0.15)
#     exploit-remote: 2/35 (0.05)
#     exploit-connect: 3/10 (0.23)
#   exploit deflected to exploration: 12
#   ## Episode: 29/50 'DQL' ϵ=0.1533, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 29|Iteration 46|reward: 4483.0|last_reward_at:   46|Elapsed Time: 0:00:00||
#   Episode 29 ended at t=46
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/0 (1.00)
#     explore-remote: 0/1 (0.00)
#     explore-connect: 0/3 (0.00)
#     exploit-local: 5/3 (0.62)
#     exploit-remote: 2/23 (0.08)
#     exploit-connect: 4/4 (0.50)
#   exploit deflected to exploration: 2
#   ## Episode: 30/50 'DQL' ϵ=0.1521, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 30|Iteration 72|reward: 4483.0|last_reward_at:   72|Elapsed Time: 0:00:00||
#   Episode 30 ended at t=72
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 0/3 (0.00)
#     explore-remote: 1/8 (0.11)
#     explore-connect: 0/11 (0.00)
#     exploit-local: 6/8 (0.43)
#     exploit-remote: 2/16 (0.11)
#     exploit-connect: 3/14 (0.18)
#   exploit deflected to exploration: 14
#   ## Episode: 31/50 'DQL' ϵ=0.1503, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 31|Iteration 121|reward: 4483.0|last_reward_at:  121|Elapsed Time: 0:00:00||
#   Episode 31 ended at t=121
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 2/3 (0.40)
#     explore-remote: 1/13 (0.07)
#     explore-connect: 0/9 (0.00)
#     exploit-local: 4/11 (0.27)
#     exploit-remote: 2/47 (0.04)
#     exploit-connect: 3/26 (0.10)
#   exploit deflected to exploration: 7
#   ## Episode: 32/50 'DQL' ϵ=0.1473, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 32|Iteration 38|reward: 4468.0|last_reward_at:   38|Elapsed Time: 0:00:00||
#   Episode 32 ended at t=38
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 0/0 (NaN)
#     explore-remote: 1/7 (0.12)
#     explore-connect: 0/5 (0.00)
#     exploit-local: 5/10 (0.33)
#     exploit-remote: 0/4 (0.00)
#     exploit-connect: 4/2 (0.67)
#   exploit deflected to exploration: 7
#   ## Episode: 33/50 'DQL' ϵ=0.1464, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 33|Iteration 40|reward: 4483.0|last_reward_at:   40|Elapsed Time: 0:00:00||
#   Episode 33 ended at t=40
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 0/0 (NaN)
#     explore-remote: 0/4 (0.00)
#     explore-connect: 0/2 (0.00)
#     exploit-local: 6/4 (0.60)
#     exploit-remote: 3/15 (0.17)
#     exploit-connect: 3/3 (0.50)
#   exploit deflected to exploration: 4
#   ## Episode: 34/50 'DQL' ϵ=0.1455, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 34|Iteration 500|reward:  174.0|last_reward_at:   48|Elapsed Time: 0:00:02||
#   Episode 34 stopped at t=500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 2/13 (0.13)
#     explore-remote: 0/40 (0.00)
#     explore-connect: 0/27 (0.00)
#     exploit-local: 3/5 (0.38)
#     exploit-remote: 2/393 (0.01)
#     exploit-connect: 1/14 (0.07)
#   exploit deflected to exploration: 5
#   ## Episode: 35/50 'DQL' ϵ=0.1354, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 35|Iteration 500|reward:  483.0|last_reward_at:  455|Elapsed Time: 0:00:02||
#   Episode 35 stopped at t=500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/6 (0.14)
#     explore-remote: 1/31 (0.03)
#     explore-connect: 0/37 (0.00)
#     exploit-local: 5/40 (0.11)
#     exploit-remote: 1/369 (0.00)
#     exploit-connect: 2/7 (0.22)
#   exploit deflected to exploration: 0
#   ## Episode: 36/50 'DQL' ϵ=0.1276, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 36|Iteration 298|reward: 4483.0|last_reward_at:  298|Elapsed Time: 0:00:02||
#   Episode 36 ended at t=298
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 0/7 (0.00)
#     explore-remote: 1/16 (0.06)
#     explore-connect: 0/14 (0.00)
#     exploit-local: 6/145 (0.04)
#     exploit-remote: 2/90 (0.02)
#     exploit-connect: 3/14 (0.18)
#   exploit deflected to exploration: 0
#   ## Episode: 37/50 'DQL' ϵ=0.1238, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 37|Iteration 500|reward:  174.0|last_reward_at:  185|Elapsed Time: 0:00:02||
#   Episode 37 stopped at t=500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 0/12 (0.00)
#     explore-remote: 1/23 (0.04)
#     explore-connect: 0/21 (0.00)
#     exploit-local: 5/13 (0.28)
#     exploit-remote: 1/421 (0.00)
#     exploit-connect: 1/2 (0.33)
#   exploit deflected to exploration: 0
#   ## Episode: 38/50 'DQL' ϵ=0.1185, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 38|Iteration 500|reward:  174.0|last_reward_at:  195|Elapsed Time: 0:00:02||
#   Episode 38 stopped at t=500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 0/7 (0.00)
#     explore-remote: 1/18 (0.05)
#     explore-connect: 0/27 (0.00)
#     exploit-local: 5/0 (1.00)
#     exploit-remote: 1/440 (0.00)
#     exploit-connect: 1/0 (1.00)
#   exploit deflected to exploration: 0
#   ## Episode: 39/50 'DQL' ϵ=0.1144, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 39|Iteration 500|reward:  174.0|last_reward_at:  130|Elapsed Time: 0:00:02||
#   Episode 39 stopped at t=500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/11 (0.08)
#     explore-remote: 1/17 (0.06)
#     explore-connect: 0/21 (0.00)
#     exploit-local: 4/0 (1.00)
#     exploit-remote: 1/443 (0.00)
#     exploit-connect: 1/0 (1.00)
#   exploit deflected to exploration: 0
#   ## Episode: 40/50 'DQL' ϵ=0.1112, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 40|Iteration 500|reward:  174.0|last_reward_at:  420|Elapsed Time: 0:00:02||
#   Episode 40 stopped at t=500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/4 (0.20)
#     explore-remote: 1/19 (0.05)
#     explore-connect: 0/18 (0.00)
#     exploit-local: 4/14 (0.22)
#     exploit-remote: 1/420 (0.00)
#     exploit-connect: 1/17 (0.06)
#   exploit deflected to exploration: 0
#   ## Episode: 41/50 'DQL' ϵ=0.1088, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 41|Iteration 75|reward: 4483.0|last_reward_at:   75|Elapsed Time: 0:00:00||
#   Episode 41 ended at t=75
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 2/1 (0.67)
#     explore-remote: 1/2 (0.33)
#     explore-connect: 0/8 (0.00)
#     exploit-local: 4/12 (0.25)
#     exploit-remote: 1/33 (0.03)
#     exploit-connect: 4/7 (0.36)
#   exploit deflected to exploration: 8
#   ## Episode: 42/50 'DQL' ϵ=0.1084, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 42|Iteration 172|reward: 4483.0|last_reward_at:  172|Elapsed Time: 0:00:01||
#   Episode 42 ended at t=172
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/4 (0.20)
#     explore-remote: 1/12 (0.08)
#     explore-connect: 0/16 (0.00)
#     exploit-local: 5/18 (0.22)
#     exploit-remote: 2/50 (0.04)
#     exploit-connect: 3/60 (0.05)
#   exploit deflected to exploration: 13
#   ## Episode: 43/50 'DQL' ϵ=0.1077, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 43|Iteration 107|reward: 4483.0|last_reward_at:  107|Elapsed Time: 0:00:00||
#   Episode 43 ended at t=107
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/2 (0.33)
#     explore-remote: 2/13 (0.13)
#     explore-connect: 0/10 (0.00)
#     exploit-local: 6/4 (0.60)
#     exploit-remote: 0/26 (0.00)
#     exploit-connect: 3/40 (0.07)
#   exploit deflected to exploration: 14
#   ## Episode: 44/50 'DQL' ϵ=0.1073, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 44|Iteration 97|reward: 4474.0|last_reward_at:   97|Elapsed Time: 0:00:00||
#   Episode 44 ended at t=97
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 3/3 (0.50)
#     explore-remote: 0/11 (0.00)
#     explore-connect: 1/6 (0.14)
#     exploit-local: 3/7 (0.30)
#     exploit-remote: 1/49 (0.02)
#     exploit-connect: 3/10 (0.23)
#   exploit deflected to exploration: 8
#   ## Episode: 45/50 'DQL' ϵ=0.1070, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 45|Iteration 24|reward: 4468.0|last_reward_at:   24|Elapsed Time: 0:00:00||
#   Episode 45 ended at t=24
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 0/1 (0.00)
#     explore-remote: 0/1 (0.00)
#     explore-connect: 0/3 (0.00)
#     exploit-local: 5/6 (0.45)
#     exploit-remote: 1/1 (0.50)
#     exploit-connect: 4/2 (0.67)
#   exploit deflected to exploration: 2
#   ## Episode: 46/50 'DQL' ϵ=0.1069, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 46|Iteration 85|reward: 4474.0|last_reward_at:   85|Elapsed Time: 0:00:00||
#   Episode 46 ended at t=85
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 0/4 (0.00)
#     explore-remote: 0/8 (0.00)
#     explore-connect: 0/5 (0.00)
#     exploit-local: 7/11 (0.39)
#     exploit-remote: 1/20 (0.05)
#     exploit-connect: 3/26 (0.10)
#   exploit deflected to exploration: 9
#   ## Episode: 47/50 'DQL' ϵ=0.1066, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 47|Iteration 52|reward: 4474.0|last_reward_at:   52|Elapsed Time: 0:00:00||
#   Episode 47 ended at t=52
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 2/4 (0.33)
#     explore-remote: 0/6 (0.00)
#     explore-connect: 0/4 (0.00)
#     exploit-local: 4/9 (0.31)
#     exploit-remote: 2/9 (0.18)
#     exploit-connect: 3/9 (0.25)
#   exploit deflected to exploration: 11
#   ## Episode: 48/50 'DQL' ϵ=0.1064, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 48|Iteration 46|reward: 4483.0|last_reward_at:   46|Elapsed Time: 0:00:00||
#   Episode 48 ended at t=46
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/5 (0.17)
#     explore-remote: 2/9 (0.18)
#     explore-connect: 0/3 (0.00)
#     exploit-local: 5/3 (0.62)
#     exploit-remote: 1/5 (0.17)
#     exploit-connect: 3/9 (0.25)
#   exploit deflected to exploration: 16
#   ## Episode: 49/50 'DQL' ϵ=0.1063, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 49|Iteration 155|reward: 4483.0|last_reward_at:  155|Elapsed Time: 0:00:01||
#   Episode 49 ended at t=155
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 2/6 (0.25)
#     explore-remote: 1/14 (0.07)
#     explore-connect: 0/18 (0.00)
#     exploit-local: 5/7 (0.42)
#     exploit-remote: 1/49 (0.02)
#     exploit-connect: 3/49 (0.06)
#   exploit deflected to exploration: 29
#   ## Episode: 50/50 'DQL' ϵ=0.1058, γ=0.015, lr=0.01, replaymemory=10000,
# batch=512, target_update=4
# Episode 50|Iteration 50|reward: 4468.0|last_reward_at:   50|Elapsed Time: 0:00:00||
#   Episode 50 ended at t=50
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/1 (0.50)
#     explore-remote: 0/8 (0.00)
#     explore-connect: 1/15 (0.06)
#     exploit-local: 4/1 (0.80)
#     exploit-remote: 1/7 (0.12)
#     exploit-connect: 3/8 (0.27)
#   exploit deflected to exploration: 16
# simulation ended

# %%
random_run = learner.epsilon_greedy_search(
    gym_env,
    ep,
    learner=learner.RandomPolicy(),
    episode_count=eval_episode_count,
    iteration_count=iteration_count,
    epsilon=1.0,  # purely random
    render=False,
    verbosity=Verbosity.Quiet,
    plot_episodes_length=False,
    title="Random search"
)
# Out:
# ###### Random search
# Learning with: episode_count=10,iteration_count=500,ϵ=1.0,ϵ_min=0.0,
#   ## Episode: 1/10 'Random search' ϵ=1.0000,
# Episode 1|Iteration 500|reward:  483.0|last_reward_at:  413|Elapsed Time: 0:00:00||
#   Episode 1 stopped at t=500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 6/91 (0.06)
#     explore-remote: 2/190 (0.01)
#     explore-connect: 2/209 (0.01)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
#   ## Episode: 2/10 'Random search' ϵ=1.0000,
# Episode 2|Iteration 500|reward:  474.0|last_reward_at:  493|Elapsed Time: 0:00:00||
#   Episode 2 stopped at t=500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 5/78 (0.06)
#     explore-remote: 2/208 (0.01)
#     explore-connect: 2/205 (0.01)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
#   ## Episode: 3/10 'Random search' ϵ=1.0000,
# Episode 3|Iteration 500|reward:  174.0|last_reward_at:  174|Elapsed Time: 0:00:00||
#   Episode 3 stopped at t=500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 5/86 (0.05)
#     explore-remote: 2/201 (0.01)
#     explore-connect: 1/205 (0.00)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
#   ## Episode: 4/10 'Random search' ϵ=1.0000,
# Episode 4|Iteration 500|reward:  174.0|last_reward_at:   51|Elapsed Time: 0:00:00||
#   Episode 4 stopped at t=500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 5/88 (0.05)
#     explore-remote: 2/202 (0.01)
#     explore-connect: 1/202 (0.00)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
#   ## Episode: 5/10 'Random search' ϵ=1.0000,
# Episode 5|Iteration 500|reward:  174.0|last_reward_at:  258|Elapsed Time: 0:00:00||
#   Episode 5 stopped at t=500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 5/93 (0.05)
#     explore-remote: 2/205 (0.01)
#     explore-connect: 1/194 (0.01)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
#   ## Episode: 6/10 'Random search' ϵ=1.0000,
# Episode 6|Iteration 500|reward:  174.0|last_reward_at:   59|Elapsed Time: 0:00:00||
#   Episode 6 stopped at t=500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 5/87 (0.05)
#     explore-remote: 2/205 (0.01)
#     explore-connect: 1/200 (0.00)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
#   ## Episode: 7/10 'Random search' ϵ=1.0000,
# Episode 7|Iteration 500|reward:  483.0|last_reward_at:  211|Elapsed Time: 0:00:00||
#   Episode 7 stopped at t=500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 6/96 (0.06)
#     explore-remote: 2/189 (0.01)
#     explore-connect: 2/205 (0.01)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
#   ## Episode: 8/10 'Random search' ϵ=1.0000,
# Episode 8|Iteration 348|reward: 4483.0|last_reward_at:  348|Elapsed Time: 0:00:00||
#   Episode 8 ended at t=348
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 6/57 (0.10)
#     explore-remote: 2/139 (0.01)
#     explore-connect: 4/140 (0.03)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
#   ## Episode: 9/10 'Random search' ϵ=1.0000,
# Episode 9|Iteration 500|reward:  174.0|last_reward_at:  137|Elapsed Time: 0:00:00||
#   Episode 9 stopped at t=500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 5/81 (0.06)
#     explore-remote: 2/200 (0.01)
#     explore-connect: 1/211 (0.00)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
#   ## Episode: 10/10 'Random search' ϵ=1.0000,
# Episode 10|Iteration 500|reward:  483.0|last_reward_at:  408|Elapsed Time: 0:00:00||
#   Episode 10 stopped at t=500
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 6/91 (0.06)
#     explore-remote: 2/197 (0.01)
#     explore-connect: 2/202 (0.01)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
# simulation ended

# %%
all_runs = [
    random_run,
    credlookup_run,
    dql_run,
]

# Plot averaged cumulative rewards for DQL vs Random vs DQL-Exploit
themodel = dqla.CyberBattleStateActionModel(ep)
p.plot_averaged_cummulative_rewards(
    all_runs=all_runs,
    title=f'Benchmark -- max_nodes={ep.maximum_node_count}, episodes={eval_episode_count},\n'
    f'State: {[f.name() for f in themodel.state_space.feature_selection]} '
    f'({len(themodel.state_space.feature_selection)}\n'
    f"Action: abstract_action ({themodel.action_space.flat_size()})")

# %%
contenders = [
    random_run,
    credlookup_run,
    dql_run,
]
p.plot_episodes_length(contenders)
p.plot_averaged_cummulative_rewards(
    title=f'Agent Benchmark top contenders\n'
    f'max_nodes:{ep.maximum_node_count}\n',
    all_runs=contenders)

# %%
for r in contenders:
    p.plot_all_episodes(r)
